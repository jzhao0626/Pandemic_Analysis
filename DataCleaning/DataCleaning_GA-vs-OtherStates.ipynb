# %%
# Dependencies
import pandas as pd

# %%
csvpath1 = 'Resources/all-states-history.csv'
States_df = pd.read_csv(csvpath1)
States_df
# Out:
#              date state dataQualityGrade    death  deathConfirmed  \
# 0      2021-02-08    AK                A    279.0             NaN
# 1      2021-02-08    AL                A   8523.0          6753.0
# 2      2021-02-08    AR               A+   5106.0          4081.0
# 3      2021-02-08    AS              NaN      0.0             NaN
# 4      2021-02-08    AZ               A+  14055.0         12487.0
# ...           ...   ...              ...      ...             ...
# 19256  2020-01-17    WA              NaN      NaN             NaN
# 19257  2020-01-16    WA              NaN      NaN             NaN
# 19258  2020-01-15    WA              NaN      NaN             NaN
# 19259  2020-01-14    WA              NaN      NaN             NaN
# 19260  2020-01-13    WA              NaN      NaN             NaN
#
#        deathIncrease  deathProbable  hospitalized  hospitalizedCumulative  \
# 0                  0            NaN        1219.0                  1219.0
# ...

# %%
filtered_States_df = States_df[['state','date','positive','death']]
renamed_States_df = filtered_States_df.rename(columns={'state':'State', 'date':'Date',
                                                       'positive':'Cumulative Cases', 
                                                       'death':'Cumulative Deaths'})
grouped_States_df = cleaned_States_df.groupby('State')
latest_States_df = grouped_States_df.max()
latest_States_df
lowest_cases = latest_States_df.loc['VT', 'Cumulative Cases']
cleaned_States_df = latest_States_df.loc[latest_States_df['Cumulative Cases'] >= lowest_state]
cleaned_States_df
# Out:
#              Date  Cumulative Cases  Cumulative Deaths
# State
# AK     2021-02-08           53694.0              279.0
# AL     2021-02-08          473348.0             8523.0
# AR     2021-02-08          307373.0             5106.0
# AZ     2021-02-08          782887.0            14055.0
# CA     2021-02-08         3346340.0            44150.0
# CO     2021-02-08          406276.0             5733.0
# CT     2021-02-08          263739.0             7282.0
# DC     2021-02-08           38136.0              956.0
# DE     2021-02-08           80931.0             1208.0
# FL     2021-02-08         1751343.0            28287.0
# GA     2021-02-08          943695.0            15130.0
# HI     2021-02-08           27195.0              418.0
# IA     2021-02-08          271698.0             5110.0
# ID     2021-02-08          165209.0             1767.0
# IL     2021-02-08         1148088.0            21779.0
# IN     2021-02-08          640744.0            11875.0
# ...

# %%
cleaned_States_df.to_csv('Output/StatesCases.csv')
