# %%
# Dependencies
import pandas as pd

# %%
csvpath = 'Resources/Average_Household_Size_and_Population_Density_-_County.csv'
PopDen_df = pd.read_csv(csvpath)
PopDen_df
# Out:
#        FID  COUNTYNS  GEOID       ALAND      AWATER                 NAME  \
# 0        1    161526   1001  1539602123    25706961       Autauga County
# 1        2    161527   1003  4117546676  1133055836       Baldwin County
# 2        3    161528   1005  2292144655    50538698       Barbour County
# 3        4    161529   1007  1612167481     9602089          Bibb County
# 4        5    161530   1009  1670103911    15015423        Blount County
# ...    ...       ...    ...         ...         ...                  ...
# 3215  3216   1804553  72145   118777649    57795019  Vega Baja Municipio
# 3216  3217   1804554  72147   131541395   552192819    Vieques Municipio
# 3217  3218   1804555  72149    92298569     3622639   Villalba Municipio
# 3218  3219   1804556  72151   143005179    72592521    Yabucoa Municipio
# 3219  3220   1804557  72153   175371916     1625259      Yauco Municipio
#
#             State  B25010_001E  B25010_001M  B25010_002E  ...  B01001_001E  \
# ...

# %%
filtered_df = PopDen_df[['State','NAME','B01001_calc_PopDensity']]
filtered_df
# Out:
#             State                 NAME  B01001_calc_PopDensity
# 0         Alabama       Autauga County               35.853419
# 1         Alabama       Baldwin County               50.541504
# 2         Alabama       Barbour County               11.247981
# 3         Alabama          Bibb County               13.973114
# 4         Alabama        Blount County               34.515816
# ...           ...                  ...                     ...
# 3215  Puerto Rico  Vega Baja Municipio              449.335380
# 3216  Puerto Rico    Vieques Municipio               66.678630
# 3217  Puerto Rico   Villalba Municipio              249.115455
# 3218  Puerto Rico    Yabucoa Municipio              238.795547
# 3219  Puerto Rico      Yauco Municipio              207.781273
#
# [3220 rows x 3 columns]

# %%
filtered_df.to_csv('Output/PopulationDensity.csv')
