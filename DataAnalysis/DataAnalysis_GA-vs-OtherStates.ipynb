# %%
# Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import linregress

# %%
csvpath = '../DataCleaning/Output/StatesCases.csv'
final_df = pd.read_csv(csvpath)
final_df
# Out:
#    State        Date  Cumulative Cases  Cumulative Deaths
# 0     AK  2021-02-08           53694.0              279.0
# 1     AL  2021-02-08          473348.0             8523.0
# 2     AR  2021-02-08          307373.0             5106.0
# 3     AZ  2021-02-08          782887.0            14055.0
# 4     CA  2021-02-08         3346340.0            44150.0
# 5     CO  2021-02-08          406276.0             5733.0
# 6     CT  2021-02-08          263739.0             7282.0
# 7     DC  2021-02-08           38136.0              956.0
# 8     DE  2021-02-08           80931.0             1208.0
# 9     FL  2021-02-08         1751343.0            28287.0
# 10    GA  2021-02-08          943695.0            15130.0
# 11    HI  2021-02-08           27195.0              418.0
# 12    IA  2021-02-08          271698.0             5110.0
# 13    ID  2021-02-08          165209.0             1767.0
# 14    IL  2021-02-08         1148088.0            21779.0
# 15    IN  2021-02-08          640744.0            11875.0
# 16    KS  2021-02-08          282960.0             4197.0
# 17    KY  2021-02-08          378793.0             4091.0
# 18    LA  2021-02-08          412989.0             9142.0
# 19    MA  2021-02-08          545303.0            15054.0
# 20    MD  2021-02-08          364553.0             7372.0
# 21    ME  2021-02-08           41419.0              636.0
# 22    MI  2021-02-08          622813.0            15863.0
# 23    MN  2021-02-08          468682.0             6302.0
# 24    MO  2021-02-08          466664.0             7143.0
# 25    MS  2021-02-08          282313.0             6270.0
# 26    MT  2021-02-08           95914.0             1314.0
# 27    NC  2021-02-08          799279.0             9991.0
# 28    ND  2021-02-08           98184.0             1454.0
# 29    NE  2021-02-08          193826.0             1968.0
# 30    NH  2021-02-08           68499.0             1106.0
# 31    NJ  2021-02-08          724728.0            22011.0
# 32    NM  2021-02-08          177867.0             3412.0
# 33    NV  2021-02-08          284590.0             4522.0
# 34    NY  2021-02-08         1479220.0            36339.0
# 35    OH  2021-02-08          922143.0            11695.0
# 36    OK  2021-02-08          404994.0             3817.0
# 37    OR  2021-02-08          147122.0             2023.0
# 38    PA  2021-02-08          872825.0            22471.0
# 39    PR  2021-02-08           96161.0             1888.0
# 40    RI  2021-02-08          119104.0             2236.0
# 41    SC  2021-02-08          468403.0             7690.0
# 42    SD  2021-02-08          109283.0             1809.0
# 43    TN  2021-02-08          745826.0            10566.0
# 44    TX  2021-02-08         2491227.0            38700.0
# 45    UT  2021-02-08          355122.0             1738.0
# 46    VA  2021-02-08          530825.0             6820.0
# 47    VT  2021-02-08           13046.0              183.0
# 48    WA  2021-02-08          320146.0             4449.0
# 49    WI  2021-02-08          601391.0             6614.0
# 50    WV  2021-02-08          125106.0             2131.0
# 51    WY  2021-02-08           52784.0              624.0

# %%
final_df.plot(kind='bar', x='State', y='Cumulative Cases', figsize=(16,8), rot = 0, title='Cumulative Cases of Each State')
plt.ylabel('Cumulative Cases')
# Out:
# Text(0, 0.5, 'Cumulative Cases')

# %%
final_df.plot(kind='bar', x='State', y='Cumulative Deaths', figsize=(16,8), rot = 0, title='Cumulative Deaths of Each State', color='r')
plt.ylabel('Cumulative Death')
# Out:
# Text(0, 0.5, 'Cumulative Death')

# %%
sorted_cases_df = final_df.sort_values('Cumulative Cases', ascending=False)
sorted_final_df.plot(kind='bar', x='State', y='Cumulative Cases', figsize=(20,8), rot = 0, title='Cumulative Cases of Each State')
plt.ylabel('Cumulative Cases')
plt.savefig('Figures/Cumulative_Cases_of_Each_State.png')

# %%
sorted_deaths_df = final_df.sort_values('Cumulative Deaths', ascending=False)
sorted_deaths_df.plot(kind='bar', x='State', y='Cumulative Deaths', figsize=(20,8), rot = 0, title='Cumulative Deaths of Each State', color='r')
plt.ylabel('Cumulative Death')
plt.savefig('Figures/Cumulative_Deaths_of_Each_State.png')

# %%
top_cases_df = sorted_cases_df.iloc[0:10]
plt.figure(figsize=(16,8))
top_case_graph = plt.bar(top_cases_df['State'], top_cases_df['Cumulative Cases'])
top_case_graph[5].set_color('r')
plt.title('States of Most Cases')
plt.xlabel('State')
plt.ylabel('Cumulative Cases')
plt.savefig('Figures/Cumulative_Cases_of_Top_State.png')

# %%
top_deaths_df = sorted_deaths_df.iloc[0:10]
plt.figure(figsize=(16,8))
top_death_graph = plt.bar(top_deaths_df['State'], top_deaths_df['Cumulative Deaths'], color='r')
top_death_graph[8].set_color('m')
plt.title('States of Most Deaths')
plt.xlabel('State')
plt.ylabel('Cumulative Deaths')
plt.savefig('Figures/Cumulative_Deaths_of_Top_State.png')
